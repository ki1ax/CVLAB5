# %%
# !git clone https://github.com/timesler/facenet-pytorch.git facenet_pytorch
from facenet_pytorch import MTCNN
import torch
import numpy as np

# !pip install -U openmim
# !mim install mmcv
import mmcv, cv2
from PIL import Image, ImageDraw
from IPython import display

from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.models import Model
# Out:
# "git" не является внутренней или внешней
# командой, исполняемой программой или пакетным файлом.
# Collecting openmim
#   Downloading openmim-0.3.7-py2.py3-none-any.whl (51 kB)
#      -------------------------------------- 51.3/51.3 kB 652.0 kB/s eta 0:00:00
# Requirement already satisfied: tabulate in c:\users\mrant\anaconda3\lib\site-packages (from openmim) (0.8.10)
# Collecting model-index
#   Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Requirement already satisfied: colorama in c:\users\mrant\anaconda3\lib\site-packages (from openmim) (0.4.6)
# Requirement already satisfied: Click in c:\users\mrant\anaconda3\lib\site-packages (from openmim) (8.0.4)
# Requirement already satisfied: pandas in c:\users\mrant\anaconda3\lib\site-packages (from openmim) (1.5.3)
# Requirement already satisfied: requests in c:\users\mrant\anaconda3\lib\site-packages (from openmim) (2.28.1)
# Requirement already satisfied: rich in c:\users\mrant\appdata\roaming\python\python310\site-packages (from openmim) (13.4.1)
# Requirement already satisfied: pip>=19.3 in c:\users\mrant\anaconda3\lib\site-packages (from openmim) (22.3.1)
# Requirement already satisfied: markdown in c:\users\mrant\anaconda3\lib\site-packages (from model-index->openmim) (3.4.1)
# Requirement already satisfied: pyyaml in c:\users\mrant\anaconda3\lib\site-packages (from model-index->openmim) (6.0)
# Collecting ordered-set
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mrant\anaconda3\lib\site-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mrant\anaconda3\lib\site-packages (from pandas->openmim) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\mrant\anaconda3\lib\site-packages (from pandas->openmim) (1.23.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mrant\anaconda3\lib\site-packages (from requests->openmim) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mrant\anaconda3\lib\site-packages (from requests->openmim) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mrant\anaconda3\lib\site-packages (from requests->openmim) (2023.5.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\mrant\anaconda3\lib\site-packages (from requests->openmim) (2.0.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mrant\appdata\roaming\python\python310\site-packages (from rich->openmim) (2.15.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\mrant\appdata\roaming\python\python310\site-packages (from rich->openmim) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mrant\appdata\roaming\python\python310\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\mrant\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->openmim) (1.16.0)
# Installing collected packages: ordered-set, model-index, openmim
# Successfully installed model-index-0.1.11 openmim-0.3.7 ordered-set-4.1.0
# Looking in links: https://download.openmmlab.com/mmcv/dist/cpu/torch2.0.0/index.html
# Collecting mmcv
#   Downloading https://download.openmmlab.com/mmcv/dist/cpu/torch2.0.0/mmcv-2.0.0-cp310-cp310-win_amd64.whl (975 kB)
#      -------------------------------------- 975.7/975.7 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: mmengine>=0.2.0 in c:\users\mrant\appdata\roaming\python\python310\site-packages (from mmcv) (0.7.4)
# Requirement already satisfied: opencv-python>=3 in c:\users\mrant\appdata\roaming\python\python310\site-packages (from mmcv) (4.7.0.72)
# Requirement already satisfied: numpy in c:\users\mrant\anaconda3\lib\site-packages (from mmcv) (1.23.5)
# Requirement already satisfied: addict in c:\users\mrant\appdata\roaming\python\python310\site-packages (from mmcv) (2.4.0)
# Requirement already satisfied: packaging in c:\users\mrant\anaconda3\lib\site-packages (from mmcv) (22.0)
# Requirement already satisfied: regex in c:\users\mrant\anaconda3\lib\site-packages (from mmcv) (2022.7.9)
# Requirement already satisfied: yapf in c:\users\mrant\anaconda3\lib\site-packages (from mmcv) (0.31.0)
# Requirement already satisfied: Pillow in c:\users\mrant\anaconda3\lib\site-packages (from mmcv) (9.4.0)
# Requirement already satisfied: pyyaml in c:\users\mrant\anaconda3\lib\site-packages (from mmcv) (6.0)
# Requirement already satisfied: rich in c:\users\mrant\appdata\roaming\python\python310\site-packages (from mmengine>=0.2.0->mmcv) (13.4.1)
# Requirement already satisfied: matplotlib in c:\users\mrant\anaconda3\lib\site-packages (from mmengine>=0.2.0->mmcv) (3.7.0)
# Requirement already satisfied: termcolor in c:\users\mrant\anaconda3\lib\site-packages (from mmengine>=0.2.0->mmcv) (2.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mrant\anaconda3\lib\site-packages (from matplotlib->mmengine>=0.2.0->mmcv) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mrant\anaconda3\lib\site-packages (from matplotlib->mmengine>=0.2.0->mmcv) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\mrant\anaconda3\lib\site-packages (from matplotlib->mmengine>=0.2.0->mmcv) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mrant\anaconda3\lib\site-packages (from matplotlib->mmengine>=0.2.0->mmcv) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mrant\anaconda3\lib\site-packages (from matplotlib->mmengine>=0.2.0->mmcv) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mrant\anaconda3\lib\site-packages (from matplotlib->mmengine>=0.2.0->mmcv) (1.4.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mrant\appdata\roaming\python\python310\site-packages (from rich->mmengine>=0.2.0->mmcv) (2.15.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\mrant\appdata\roaming\python\python310\site-packages (from rich->mmengine>=0.2.0->mmcv) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mrant\appdata\roaming\python\python310\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->mmengine>=0.2.0->mmcv) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\mrant\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.2.0->mmcv) (1.16.0)
# Installing collected packages: mmcv
# Successfully installed mmcv-2.0.0

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('Running on device: {}'.format(device))
# Out:
# Running on device: cpu

# %%
mtcnn = MTCNN(keep_all=True, device=device)

# %%
video = mmcv.VideoReader('ЛЕС1.mp4')
frames = [Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)) for frame in video]

display.Video('ЛЕС1.mp4', width=640)
# Out:
# <video src="ЛЕС1.mp4" controls  width="640" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
frames_tracked = []
for i, frame in enumerate(frames):
    print('\rTracking frame: {}'.format(i + 1), end='')
    boxes, _  = mtcnn.detect(frame)
    frame_draw = frame.copy()
    draw = ImageDraw.Draw(frame_draw)
    for box in boxes:
        draw.rectangle(box.tolist(), outline=(255, 0, 0), width=6)
    frames_tracked.append(frame_draw.resize((640, 360), Image.BILINEAR))
print('\nDone')
# Out:
# Tracking frame: 85
# Done

# %%
d = display.display(frames_tracked[0], display_id=True)
i = 1
try:
    while True:
        d.update(frames_tracked[i % len(frames_tracked)])
        i += 1
except KeyboardInterrupt:
    pass
# Out:
# <PIL.Image.Image image mode=RGB size=640x360>
